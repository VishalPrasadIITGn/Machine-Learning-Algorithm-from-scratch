# %% [markdown]
# # Vishal Prasad ML A7 (18210095)

# %% [markdown]
# # Question No. 1 (a):

# %% [markdown]
# ### Reading the data

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("irisself.txt") # Import data
temp=df.iloc[:,-1]
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        label
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.drop('SepalWidth',axis=1,inplace=True)
df.drop('PetalLength',axis=1,inplace=True)
df.head(100)
# Out:
#     SepalLength  PetalWidth            label
# 0           5.1         0.2      Iris-setosa
# 1           4.9         0.2      Iris-setosa
# 2           4.7         0.2      Iris-setosa
# 3           4.6         0.2      Iris-setosa
# 4           5.0         0.2      Iris-setosa
# 5           5.4         0.4      Iris-setosa
# 6           4.6         0.3      Iris-setosa
# 7           5.0         0.2      Iris-setosa
# 8           4.4         0.2      Iris-setosa
# 9           4.9         0.1      Iris-setosa
# 10          5.4         0.2      Iris-setosa
# 11          4.8         0.2      Iris-setosa
# 12          4.8         0.1      Iris-setosa
# 13          4.3         0.1      Iris-setosa
# 14          5.8         0.2      Iris-setosa
# 15          5.7         0.4      Iris-setosa
# 16          5.4         0.4      Iris-setosa
# 17          5.1         0.3      Iris-setosa
# 18          5.7         0.3      Iris-setosa
# 19          5.1         0.3      Iris-setosa
# 20          5.4         0.2      Iris-setosa
# 21          5.1         0.4      Iris-setosa
# 22          4.6         0.2      Iris-setosa
# 23          5.1         0.5      Iris-setosa
# 24          4.8         0.2      Iris-setosa
# 25          5.0         0.2      Iris-setosa
# 26          5.0         0.4      Iris-setosa
# 27          5.2         0.2      Iris-setosa
# 28          5.2         0.2      Iris-setosa
# 29          4.7         0.2      Iris-setosa
# ..          ...         ...              ...
# 70          5.9         1.8  Iris-versicolor
# 71          6.1         1.3  Iris-versicolor
# 72          6.3         1.5  Iris-versicolor
# 73          6.1         1.2  Iris-versicolor
# 74          6.4         1.3  Iris-versicolor
# 75          6.6         1.4  Iris-versicolor
# 76          6.8         1.4  Iris-versicolor
# 77          6.7         1.7  Iris-versicolor
# 78          6.0         1.5  Iris-versicolor
# 79          5.7         1.0  Iris-versicolor
# 80          5.5         1.1  Iris-versicolor
# 81          5.5         1.0  Iris-versicolor
# 82          5.8         1.2  Iris-versicolor
# 83          6.0         1.6  Iris-versicolor
# 84          5.4         1.5  Iris-versicolor
# 85          6.0         1.6  Iris-versicolor
# 86          6.7         1.5  Iris-versicolor
# 87          6.3         1.3  Iris-versicolor
# 88          5.6         1.3  Iris-versicolor
# 89          5.5         1.3  Iris-versicolor
# 90          5.5         1.2  Iris-versicolor
# 91          6.1         1.4  Iris-versicolor
# 92          5.8         1.2  Iris-versicolor
# 93          5.0         1.0  Iris-versicolor
# 94          5.6         1.3  Iris-versicolor
# 95          5.7         1.2  Iris-versicolor
# 96          5.7         1.3  Iris-versicolor
# 97          6.2         1.3  Iris-versicolor
# 98          5.1         1.1  Iris-versicolor
# 99          5.7         1.3  Iris-versicolor
#
# [100 rows x 3 columns]

# %%
df.head(10)
temp.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: label, dtype: object

# %% [markdown]
# ### Changing labels

# %%
#data.Gender[data.Gender == 'female'] = 2
#print(data) 
df.label[df.label=='Iris-setosa']=1
df.label[df.label=='Iris-virginica']=-1
df.label[df.label=='Iris-versicolor']=-1
df.head(5)
# Out:
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    SepalLength  PetalWidth label
# 0          5.1         0.2     1
# 1          4.9         0.2     1
# 2          4.7         0.2     1
# 3          4.6         0.2     1
# 4          5.0         0.2     1

# %%
#df.head(150)

# %%
df=df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    SepalLength  PetalWidth label
# 0          6.5         2.0    -1
# 1          5.6         1.5    -1
# 2          5.6         1.3    -1
# 3          5.8         0.2     1
# 4          7.2         1.6    -1

# %%
# Form SVM with L1 regularization problem.
from cvxpy import *

# %%
df.head()
# Out:
#    SepalLength  PetalWidth label
# 0          6.5         2.0    -1
# 1          5.6         1.5    -1
# 2          5.6         1.3    -1
# 3          5.8         0.2     1
# 4          7.2         1.6    -1

# %% [markdown]
# ## 1 (A) Hard Margin SVM Function

# %%
import cvxpy as cp
def hard_margin_SVM(X,Y):
    #print(X.shape())
    n=2
    w = cp.Variable(n)
    #print(X@beta)
    b = cp.Variable()
    loss = cp.sum_entries(cp.pos(1 - cp.mul_elemwise(Y, X*w + b)))
    #reg = norm(beta, 1)
    #lambd = Parameter(nonneg=True)
    prob = Problem(Minimize(loss))# + lambd*reg))
    prob.solve()
    print(w.value,b.value)
    return w,b

# %% [markdown]
# ## 1 (A) (i)
# Hard Margin SVM Function for IRIS dataset

# %%
X=df.iloc[:,[0,2]].values
Y=df.iloc[:,-1].values
w1,b1=hard_margin_SVM(X,Y)
# Out:
# [[-0.11339071]
#  [ 2.06889053]] 0.5282505131049033

# %% [markdown]
# #### Extra direct implementation

# %%
import cvxpy as cp
X=df.iloc[:,[0,2]].values
Y=df.iloc[:,-1].values
#print(X.shape())
n=2
w = cp.Variable(n)
#print(X@beta)
b = cp.Variable()

constraints = [Y[i]*(((w[0]*X[i,0])+(w[1]*X[i,1]))+b)>1 for i in range(df.iloc[:,1].shape[0])]
#constraints = [y[i]*(np.dot(w[0:2],x[i,:])+w[2])>=1 for i in range(irp.iloc[:,1].shape[0])]
# Form objective.
obj = cp.Minimize(cp.norm(w,2)**2)

##loss = cp.sum_entries(cp.pos(1 - cp.mul_elemwise(Y, X*w + b)))
#reg = norm(beta, 1)
#lambd = Parameter(nonneg=True)
##prob = Problem(Minimize(loss))# + lambd*reg))
prob=cp.Problem(obj,constraints)
prob.solve()
w.value
b.value
# Out:
# 1.786742247981954e-10

# %%
print(w.value,b.value)
w_1=w[0].value
w_2=w[1].value
b_1=b.value
# Out:
# [[-3.34388422e-11]
#  [ 1.00000000e+00]] 1.786742247981954e-10

# %% [markdown]
# ## 1(A) (ii)
# Dual values using CVXPY

# %%
w2 = cp.Variable(n)
b2 = cp.Variable()
reg = norm(w2, 2)
#loss =
obj=cp.Minimize(reg)
constraints=[(cp.mul_elemwise(Y, X*w2 - b2))>=1]
prob2=cp.Problem(obj,constraints)
prob2.solve()
dual_vals=(constraints[0].dual_value)
#print(b.value)
#print("optimal (x - y >= 1) dual variable", constraints[1].dual_value)
#print("x - y value:", (x - y).value)

# %%
print(w2.value)
indxs=sorted(range(len(dual_vals)), key=lambda i: dual_vals[i], reverse=True)[:20]
# Out:
# [[-1.13105154e-11]
#  [ 1.00000000e+00]]

# %% [markdown]
# #### Examples with larger dual values have large importance in deciding the boundary

# %% [markdown]
# ## 1(A) (iii)
# Plotting hperplane boundary

# %%
import matplotlib.pyplot as plt
plt.scatter(df.iloc[:,0],df.iloc[:,1],c=df.iloc[:,-1])
plt.scatter(df.iloc[indxs,0],df.iloc[indxs,1],c=df.iloc[indxs,-1],facecolors='',edgecolors='k')
#plt.plot(w[0].value,w[1].value)
x1=np.linspace(4, 8, 10)
x2=(-w_1*x1+b_1)/w_2
x3=((-w_1*x1+b_1-1)/w_2)
x4=((-w_1*x1+b_1+1)/w_2)
plt.plot(x1,x2)
plt.plot(x1,x3,'k--')
plt.plot(x1,x4,'k--')
#plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, cmap=plt.cm.Paired)
plt.show()

# %% [markdown]
# #  ============Recycle Bin===============

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear', gamma='auto')
clf.fit(df.iloc[:,0:2],temp)
a=clf.support_vectors_
#print(a.shape)

# %%
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(4, 8)
yy = a * xx - (clf.intercept_[0]) / w[1]

# plot the parallels to the separating hyperplane that pass through the
# support vectors
b = clf.support_vectors_[0]
yy_down = a * xx + (b[1] - a * b[0])
b = clf.support_vectors_[-1]
yy_up = a * xx + (b[1] - a * b[0])

# plot the line, the points, and the nearest vectors to the plane
plt.plot(xx, yy, 'k-')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')

# %%
def make_meshgrid(x, y, h=.02):
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy

# %%
def plot_contours(ax, clf, xx, yy, **params):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs


# we create 40 separable points
#X, y = make_blobs(n_samples=40, centers=2, random_state=6)
X=df.iloc[:,0:2]
#y=df.iloc[:,-1]
y=temp
# fit the model, don't regularize for illustration purposes
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X, y)

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=df.iloc[:,-1], s=30, cmap=plt.cm.Paired)

# plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# create grid to evaluate model
#xx = np.linspace(xlim[0], xlim[1], 30)
#yy = np.linspace(ylim[0], ylim[1], 30)
#YY, XX = np.meshgrid(yy, xx)
YY, XX =make_meshgrid(X.iloc[:,0],X.iloc[:,1])
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf.predict(np.c_[XX.ravel(), YY.ravel()])
Z = Z.reshape(XX.shape)
print(Z.shape)
#Z = clf.decision_function(xy).reshape(XX.shape)
l=np.zeros(Z.shape)
#print(l.shape)
for p in range(len(Z)):
    for q in range(len(Z[0])):
        if Z[p][q]=='Iris-setosa':
            l[p][q]=1
        else:
            l[p][q]=-1
l=np.asarray(l)
l=l.reshape(Z.shape)
#s=np.zeros([30,1])
print(l.shape)
#s[:,0]=l
#print(l)
# plot decision boundary and margins
ax.contour(XX, YY, l, colors='k', levels=[-1, 0, 1], alpha=0.5,
           linestyles=['--', '-', '--'])
ax.set_xlim(3, 8)
ax.set_ylim(0, 5)


# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# (220, 280)
# (220, 280)
# F:\Anacondaa\lib\site-packages\matplotlib\contour.py:1243: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %% [markdown]
# ##### -------------------xxxxxxxxxxxxxxxxxxxxxxxxxxxx----------------------------------

# %% [markdown]
# ## 1(A) (iv) decision Boundary using sklearn's SVM

# %%
## Working model
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
# we create 40 separable points
#X, y = make_blobs(n_samples=40, centers=2, random_state=6)
X=df.iloc[:,0:2]
#y=df.iloc[:,-1]
y=temp
# fit the model, don't regularize for illustration purposes
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X, y)
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(4, 8)
yy = a * xx - (clf.intercept_[0]) / w[1]

# plot the parallels to the separating hyperplane that pass through the
# support vectors
b = clf.support_vectors_[0]
yy_down = a * xx + (b[1] - a * b[0])
b = clf.support_vectors_[-1]
yy_up = a * xx + (b[1] - a * b[0])

# plot the line, the points, and the nearest vectors to the plane
plt.plot(xx, yy, 'k-')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')

plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
            s=80, facecolors='none',edgecolors='k')
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, cmap=plt.cm.Paired)

plt.axis('tight')
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
df4 = pd.read_csv("irisself.txt") # Import data
temp=df4.iloc[:,-1]
df.head()
# Out:
#    SepalLength  PetalWidth label
# 0          6.5         2.0    -1
# 1          5.6         1.5    -1
# 2          5.6         1.3    -1
# 3          5.8         0.2     1
# 4          7.2         1.6    -1

# %%
df4.label[df4.label=='Iris-setosa']='Iris-setosa'
df4.label[df4.label=='Iris-virginica']='Not-setosa'
df4.label[df4.label=='Iris-versicolor']='Not-setosa'
# Out:
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df4.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        label
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
clf = svm.SVC(kernel='linear')
clf.fit(df.iloc[:,0:2],df4.iloc[:,-1])
plt.scatter(df.iloc[:, 0], df.iloc[:, 1], c=df.iloc[:,-1], s=50, cmap=plt.cm.Paired)
ax = plt.gca()
#print(temp)
#xlim = ax.get_xlim()
#ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
print(xy.shape)
Z = clf.decision_function(xy)
Z=Z.reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=1,
          linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
          linewidth=1, facecolors='none', edgecolors='k')
plt.show()
# Out:
# (900, 2)

# %% [markdown]
# ### 1(A) (v)
# If Non-Support Vectors are thrown away that does not make a difference because,ideally alpha is zero for them, and hence do not contribute to decision boundary

# %% [markdown]
# ## Question No 1(B):
# Soft Margin SVM using CVXPY formulated as hing loss plus penalty

# %%
def soft_margin_SVM(X,Y):
    #workingg
    #X=df.iloc[:,[0,2]].values
    #Y=df.iloc[:,-1].values
    #w1,b1=hard_margin_SVM(X,Y)
    #print(Y)
    n=2
    w2 = cp.Variable(n)
    b2 = cp.Variable()
    ei=cp.Variable()
    reg = norm(w2, 2)+sum_entries(ei)
    #loss =
    obj=cp.Minimize(reg)
    constraints=[(cp.mul_elemwise(Y, X*w2 - b2))>=(1-ei)]
    prob2=cp.Problem(obj,constraints)
    prob2.solve()
    print(w2.value)
    #print(constraints[0].dual_value)
    #print(b.value)
    #print("optimal (x - y >= 1) dual variable", constraints[1].dual_value)
    #print("x - y value:", (x - y).value)
    return w2,b2,ei

# %% [markdown]
# ### Editing the dataset again

# %%
df2 = pd.read_csv("irisself.txt") # Import data
temp2=df2.iloc[:,-1]
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        label
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ### Labeling the dataset

# %%
df2.drop('PetalWidth',axis=1,inplace=True)
df2.drop('PetalLength',axis=1,inplace=True)
df2.head()
# Out:
#    SepalLength  SepalWidth        label
# 0          5.1         3.5  Iris-setosa
# 1          4.9         3.0  Iris-setosa
# 2          4.7         3.2  Iris-setosa
# 3          4.6         3.1  Iris-setosa
# 4          5.0         3.6  Iris-setosa

# %%
temp2=df2.iloc[:,-1]
temp2=temp2[:]
#print(temp)

# %%
df2.label[df2.label=='Iris-setosa']=-1
df2.label[df2.label=='Iris-virginica']=1
df2.label[df2.label=='Iris-versicolor']=-1
df2.head(5)
# Out:
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    SepalLength  SepalWidth label
# 0          5.1         3.5    -1
# 1          4.9         3.0    -1
# 2          4.7         3.2    -1
# 3          4.6         3.1    -1
# 4          5.0         3.6    -1

# %%
df3 = pd.read_csv("irisself.txt") # Import data
df3.label[df3.label=='Iris-setosa']='Not-virginica'
df3.label[df3.label=='Iris-virginica']='Iris-virginica'
df3.label[df3.label=='Iris-versicolor']='Not-virginica'
# Out:
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# F:\Anacondaa\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 1(B) (ii) : Applyying on IRIS Dataset
# with SL and SW and IV

# %%
X2=df2.iloc[:,0:2].values
Y2=df2.iloc[:,-1].values
w3,b3,e3=soft_margin_SVM(X2,Y2)
print(w3.value,b3.value,e3.value)
# Out:
# [[2.86942425e-15]
#  [8.16854144e-16]]
# [[2.86942425e-15]
#  [8.16854144e-16]] 9.900482992495394e-13 1.0000000000003724

# %%
#workingg
#X=df.iloc[:,[0,2]].values
#Y=df.iloc[:,-1].values
#w1,b1=hard_margin_SVM(X,Y)
#print(Y)
n=2
w2 = cp.Variable(n)
b2 = cp.Variable()
ei=cp.Variable()
reg = norm(w2, 2)+0.5*sum_entries(ei)
#loss =
obj=cp.Minimize(reg)
constraints=[(cp.mul_elemwise(Y2, X2*w2 - b2))>=(1-ei) , ei>=0]
prob2=cp.Problem(obj,constraints)
prob2.solve()
print(w2.value,b2.value,ei.value)
dual_vals2=(constraints[0].dual_value)
#print(dual_vals2)
#print("optimal (x - y >= 1) dual variable", constraints[1].dual_value)
#print("x - y value:", (x - y).value)
# Out:
# [[2.87325984e-14]
#  [1.39122320e-14]] 7.048168274556751e-12 1.0000000000054317

# %%
indxs2=sorted(range(len(dual_vals2)), key=lambda i: dual_vals2[i], reverse=True)[:20]
#print(dual_vals2[indxs2])

# %% [markdown]
# ### 1(B) (iii): Plotting Boundar and support vector points

# %%
print(w2.value,b2.value,ei.value)
a1=w3[0].value
a2=w3[1].value
e=e3.value
b=b3.value
x1=np.linspace(4, 8, 30)
x2=(-a1*x1)/a2
x3=(((-a1*x1+b))/a2)-e
x4=(((-a1*x1-b))/a2)+e
#print(e)
plt.plot(x1,x2)
plt.plot(x1,x3,'k--')
plt.plot(x1,x4,'k--')
plt.scatter(X2[:, 0], X2[:, 1], c=Y2, cmap=plt.cm.Paired)
plt.scatter(X2[indxs2, 0], X2[indxs2, 1], c=Y2[indxs], cmap=plt.cm.Paired,s=80, facecolors='none',edgecolors='k')
plt.show()
# Out:
# [[2.87325984e-14]
#  [1.39122320e-14]] 7.048168274556751e-12 1.0000000000054317

# %% [markdown]
# ### 1(B) (iii) Using sklearn SVM plotting decision boundar and support vector points

# %%
'''
### Working model
print(__doc__)

X=df2.iloc[:,0:2]
#y=df.iloc[:,-1]
y=df3.iloc[:,-1]
#print(y)
# fit the model, don't regularize for illustration purposes
clf = svm.SVC(kernel='linear', C=1000)
clf.fit(X, y)
w = clf.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(5, 7)
yy = a * xx - (clf.intercept_[0]) / w[1]

# plot the parallels to the separating hyperplane that pass through the
# support vectors
b = clf.support_vectors_[0]
yy_down = a * xx + (b[1] - a * b[0])
b = clf.support_vectors_[1]
yy_up = a * xx + (b[1] - a * b[0])

# plot the line, the points, and the nearest vectors to the plane
plt.plot(xx, yy, 'k-')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')

plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],
            s=80, facecolors='none',edgecolors='k')
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, cmap=plt.cm.Paired)

plt.axis('tight')
plt.show()
'''
# Out:
# "\n### Working model\nprint(__doc__)\n\nX=df2.iloc[:,0:2]\n#y=df.iloc[:,-1]\ny=df3.iloc[:,-1]\n#print(y)\n# fit the model, don't regularize for illustration purposes\nclf = svm.SVC(kernel='linear', C=1000)\nclf.fit(X, y)\nw = clf.coef_[0]\na = -w[0] / w[1]\nxx = np.linspace(5, 7)\nyy = a * xx - (clf.intercept_[0]) / w[1]\n\n# plot the parallels to the separating hyperplane that pass through the\n# support vectors\nb = clf.support_vectors_[0]\nyy_down = a * xx + (b[1] - a * b[0])\nb = clf.support_vectors_[1]\nyy_up = a * xx + (b[1] - a * b[0])\n\n# plot the line, the points, and the nearest vectors to the plane\nplt.plot(xx, yy, 'k-')\nplt.plot(xx, yy_down, 'k--')\nplt.plot(xx, yy_up, 'k--')\n\nplt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1],\n            s=80, facecolors='none',edgecolors='k')\nplt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=Y, cmap=plt.cm.Paired)\n\nplt.axis('tight')\nplt.show()\n"

# %%
clf = svm.SVC(kernel='linear')
clf.fit(X,df3.iloc[:,-1])
plt.scatter(df2.iloc[:, 0], df2.iloc[:, 1], c=temp2, s=50, cmap=plt.cm.Paired)
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
print(xy.shape)
Z = clf.decision_function(xy)
print(deg)
Z=Z.reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=1,
          linestyles=['--', '-', '--'])
# plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
          linewidth=1, facecolors='none', edgecolors='k')
plt.show()
# Out:
# (900, 2)
# 4

# %%
# by other method(in primal form)

# %%
beta = Variable(n)
v = Variable()
eii= Variable()
reg = norm(w2, 2)+sum_entries(eii)
loss = sum_entries(pos(1 - eii - mul_elemwise(Y2, X2*beta - v)))
reg = norm(beta, 1)
#lambd = Parameter(sign='positive')
prob = Problem(Minimize(loss/150 + reg))
prob.solve()
print(beta.value,v.value,eii.value)
# Out:
# [[ 6.48401639e-14]
#  [-1.20537448e-14]] -0.0045693855950540915 1.0561104246072293

# %%
print(beta.value,v.value,eii.value)
a1=beta[0].value
a2=beta[1].value
e=eii.value
b=v.value
x1=np.linspace(4, 8, 30)
x2=(-a1*x1+b)/a2
x3=((-a1*x1+b+e)/a2)
x4=((-a1*x1-b-e)/a2)
#print(e)
plt.plot(x1,x2)
plt.plot(x1,x3,'k--')
plt.plot(x1,x4,'k--')
#print(Y)
plt.scatter(X2[:, 0], X2[:, 1], c=df2.iloc[:,-1], cmap=plt.cm.Paired)
plt.show()
# Out:
# [[ 6.48401639e-14]
#  [-1.20537448e-14]] -0.0045693855950540915 1.0561104246072293

# %% [markdown]
# ## 1(B) (iv) soft margin SVM usingBF, gamma, polnomial kernel

# %%
for kernel in ('linear', 'poly', 'rbf'):
    for deg in(2,3,4):
        clf = svm.SVC(kernel=kernel, gamma=2,degree=deg)
        clf.fit(X,df3.iloc[:,-1])
        plt.scatter(df2.iloc[:, 0], df2.iloc[:, 1], c=temp2, s=50, cmap=plt.cm.Paired)
        ax = plt.gca()
        xlim = ax.get_xlim()
        ylim = ax.get_ylim()

        xx = np.linspace(xlim[0], xlim[1], 30)
        yy = np.linspace(ylim[0], ylim[1], 30)
        YY, XX = np.meshgrid(yy, xx)
        xy = np.vstack([XX.ravel(), YY.ravel()]).T
        print(xy.shape)
        Z = clf.decision_function(xy)
        print(deg)
        Z=Z.reshape(XX.shape)
        ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=1,
                  linestyles=['--', '-', '--'])
        # plot support vectors
        ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100,
                  linewidth=1, facecolors='none', edgecolors='k')
        plt.show()
# Out:
# (900, 2)
# 2
# (900, 2)
# 3
# (900, 2)
# 4
# (900, 2)
# 2
# (900, 2)
# 3
# (900, 2)
# 4
# (900, 2)
# 2
# (900, 2)
# 3
# (900, 2)
# 4

# %% [markdown]
# ###### I discussed the assignment with Deepanshu Singh, Shubham Garg, Ashish Kumar, Shreejith Srikrishnan. I referred to CVXPY and sklearn documentation and stackoverflow.
